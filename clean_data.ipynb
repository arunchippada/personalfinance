# %%
import pandas as pd
import re

# %%
data_folder = 'data'
file_name = f'{data_folder}/fidelity_funds_data.csv'

# %%
df = pd.read_csv(file_name)

# %%
def clean_blank(x):
    if pd.isna(x):
        return None
    if x == '-':
        return None
    return x

# %%
def clean_percent(x):
    match = re.search(r'([-+]?\d*\.?\d+)%', str(x))
    return float(match.group(1)) if match else x

# %%
def clean_basic(x):
    x = clean_blank(x)
    x = clean_percent(x)
    return x

# %%
def to_percent(x):
    if x is None:
        return None
    return round(100 * float(x), 2)

# %%
def extract_rating_count(x):
    if x is None:
        return pd.Series([None, None])
    match = re.search(r'([1-5]) \((\d+) Rated\)', str(x))
    return pd.Series([int(match.group(1)), int(match.group(2))]) if match else pd.Series([None, None])

# %%
def sep_rating_count(df, cols):
    for col_name in cols:
        df[[col_name, f'{col_name} Count']] = df[col_name].apply(extract_rating_count)
        df[col_name] = df[col_name].astype('Int64')
        df[f'{col_name} Count'] = df[f'{col_name} Count'].astype('Int64')
    return df

# %%
for col in df.columns:
    df[col] = df[col].apply(clean_basic)

# %%
for col in ['Expense Ratio - Net', 'Expense Ratio - Gross', 'YTD (Daily)']:
    df[col] = df[col].apply(to_percent)

# %%
df = sep_rating_count(df, ['Morningstar- Overall', 'Morningstar- 3yrs', 'Morningstar- 5yrs', 'Morningstar- 10yrs'])

# %%
extract_rating_count('1 (110 Rated)')
# Out:
# 110

# %%
df.dtypes
# Out:
# Name                           object
# Morningstar Category           object
# YTD (Daily)                   float64
# 1 Yr                           object
# 3 Yr                          float64
# 5 Yr                          float64
# 10 Yr                         float64
# Life of Fund                  float64
# Expense Ratio - Net           float64
# Expense Ratio - Gross         float64
# Morningstar- Overall            Int64
# Morningstar- 3yrs               Int64
# Morningstar- 5yrs               Int64
# Morningstar- 10yrs              Int64
# Morningstar Category Risk      object
# Standard Deviation             object
# 3 Year Sharpe Ratio            object
# Beta                           object
# R2                             object
# Manager Tenure                 object
# Inception Date                 object
# Assets (Millions)              object
# Turnover Rates                float64
# Minimum Investment            float64
# Load (Y/N)                     object
# NTF                            object
# 1-year Rank                   float64
# 3-year Rank                   float64
# 5-year Rank                   float64
# 10-year Rank                  float64
# Average Maturity               object
# Average Duration               object
# 7-Day Yield                   float64
# 30-Day Yield                  float64
# Last Dividend                  object
# 1 Month                       float64
# 3 Month                       float64
# YTD                           float64
# NAV ($)                        object
# NAV Change ($)                 object
# NAV Change (%)                 object
# 30-Day Yield (%)              float64
# 7-Day Yield (%)               float64
# Morningstar- Overall Count      Int64
# Morningstar- 3yrs Count         Int64
# Morningstar- 5yrs Count         Int64
# Morningstar- 10yrs Count        Int64
# dtype: object

# %%
df['Average Maturity'].describe()
# Out:
# count                     4014
# unique                    1699
# top       0 years (06/30/2025)
# freq                        49
# Name: Average Maturity, dtype: object

# %%
df.loc[19,:]
# Out:
# Name                          VanEck BDC Income ETF (BIZD)
# Morningstar Category                             Financial
# YTD (Daily)                                           0.99
# 1 Yr                                                  7.93
# 3 Yr                                                 12.43
# 5 Yr                                                 18.39
# 10 Yr                                                 9.97
# Life of Fund                                          8.02
# Expense Ratio - Net                                  12.86
# Expense Ratio - Gross                                12.86
# Morningstar- Overall                                     3
# Morningstar- 3yrs                                        3
# Morningstar- 5yrs                                        4
# Morningstar- 10yrs                                       3
# Morningstar Category Risk                                7
# Standard Deviation                      16.30 (07/31/2025)
# 3 Year Sharpe Ratio                      0.51 (07/31/2025)
# Beta                                     0.82 (07/31/2025)
# R2                                       0.52 (07/31/2025)
# Manager Tenure                                    13 years
# Inception Date                                  02/11/2013
# Assets (Millions)                                  1655.35
# Turnover Rates                                        17.0
# Minimum Investment                                     0.0
# Load (Y/N)                                               N
# NTF                                                   None
# 1-year Rank                                           72.0
# 3-year Rank                                           62.0
# 5-year Rank                                           42.0
# 10-year Rank                                          43.0
# Average Maturity                                      None
# Average Duration                                      None
# 7-Day Yield                                            NaN
# 30-Day Yield                                          8.65
# Last Dividend                                         None
# 1 Month                                               1.94
# 3 Month                                               8.75
# YTD                                                   2.64
# NAV ($)                                              15.85
# NAV Change ($)                                       -0.09
# NAV Change (%)                       -0.005600000000000001
# 30-Day Yield (%)                                       NaN
# 7-Day Yield (%)                                        NaN
# Morningstar- Overall Count                              96
# Morningstar- 3yrs Count                                 96
# Morningstar- 5yrs Count                                 90
# Morningstar- 10yrs Count                                75
# Name: 19, dtype: object
